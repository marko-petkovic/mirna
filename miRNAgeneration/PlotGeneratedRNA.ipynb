# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
newrna = np.load('newrna/augmentor_default_3/new_mirna_data.npy')

# %%
rna = np.load(f'D:/users/Marko/downloads/mirna/data/modmirbase_train_images.npz')['arr_0']/255

# %%
am = 10
idxs = np.random.randint(0,34721,am)

# %%
newrna.shape, rna.shape
# Out:
# ((347210, 25, 100, 3), (34721, 25, 100, 3))

# %%
fig, ax = plt.subplots(nrows = 4, ncols = am, figsize=(150,30))
for i in range(am):
    ax[0,i].imshow(rna[idxs[i]])
    ax[1,i].imshow(newrna[idxs[i]*10+2]*255)
    ax[2,i].imshow(newrna[idxs[i]*10+7]*255)
    ax[3,i].imshow(newrna[idxs[i]*10+5]*255)
    
for axxx in ax:
    for axx in axxx:
        axx.set_xticks([])
        axx.set_yticks([])
        
fig.tight_layout()

# %%
ax[0]
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)
